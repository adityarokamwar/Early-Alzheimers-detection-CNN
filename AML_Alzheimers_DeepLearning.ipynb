# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 1. Efficient B0

# %% [markdown]
# ### CNN model for Alzheimer Classifier (EfficientNetB0)

# %% [markdown]
# ### Learning Rate = 0.1

# %%
import tensorflow as tf
#syntax from https://www.tensorflow.org/api_docs/python/tf/keras/utils/image_dataset_from_directory
data = r'/content/drive/MyDrive/P-II/Dataset'
train_data = tf.keras.preprocessing.image_dataset_from_directory(
    data,
    labels = 'inferred',
    label_mode='categorical',
    validation_split=0.2,
    subset="training",
    seed=42,
    color_mode='grayscale',
    image_size=(128,128),
    batch_size=32,
)
test_data = tf.keras.preprocessing.image_dataset_from_directory(
    data,
    labels = 'inferred',
    label_mode='categorical',
    validation_split= 0.2,
    subset="validation",
    seed=42,
    color_mode= 'grayscale',
    image_size = (128,128),
    batch_size=32,
)

#Model setup
EffNet = tf.keras.applications.EfficientNetB0(include_top = False)
EffNet.trainable = True
inputs = tf.keras.layers.Input(shape=((128,128) + (1,)), name = 'input_layer')
x = EffNet(inputs)
x = tf.keras.layers.GlobalAveragePooling2D(name='global_average_pooling_layer')(x)
outputs = tf.keras.layers.Dense(4, activation = 'softmax', name='output_layer')(x)
model = tf.keras.Model(inputs, outputs)
Learning_Rate = 0.1
model.compile(loss='categorical_crossentropy', optimizer = tf.keras.optimizers.Adam(learning_rate = Learning_Rate), metrics=['accuracy'])
model.summary()

#Training the Model
graphs = model.fit(train_data, validation_data = test_data, epochs = 10, verbose = False)
pd.DataFrame(graphs.history).plot(figsize=(8,6))

#check the performance
model.evaluate(test_data)
# Out:
# Found 6400 files belonging to 4 classes.
# Using 5120 files for training.
# Found 6400 files belonging to 4 classes.
# Using 1280 files for validation.
# WARNING:tensorflow:Model was constructed with shape (None, None, None, 3) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 3), dtype=tf.float32, name='input_4'), name='input_4', description="created by layer 'input_4'"), but it was called on an input with incompatible shape (None, 128, 128, 1).
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 128, 128, 1)]     0
#
#  efficientnetb0 (Functional)  (None, None, None, 1280)  4049571
#
#  global_average_pooling_laye  (None, 1280)             0
#  r (GlobalAveragePooling2D)
#
#  output_layer (Dense)        (None, 4)                 5124
#
# =================================================================
# Total params: 4,054,695
# Trainable params: 4,012,672
# Non-trainable params: 42,023
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, None, 3) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 3), dtype=tf.float32, name='input_4'), name='input_4', description="created by layer 'input_4'"), but it was called on an input with incompatible shape (None, 128, 128, 1).
# WARNING:tensorflow:Model was constructed with shape (None, None, None, 3) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 3), dtype=tf.float32, name='input_4'), name='input_4', description="created by layer 'input_4'"), but it was called on an input with incompatible shape (None, 128, 128, 1).
# WARNING:tensorflow:Model was constructed with shape (None, None, None, 3) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 3), dtype=tf.float32, name='input_4'), name='input_4', description="created by layer 'input_4'"), but it was called on an input with incompatible shape (None, 128, 128, 1).
# 40/40 [==============================] - 11s 267ms/step - loss: 6.2020 - accuracy: 0.5070
# [6.201990604400635, 0.507031261920929]

# %% [markdown]
# ### Learning Rate = 0.01

# %%
#Model Changing the learning rate
EffNet = tf.keras.applications.EfficientNetB0(include_top = False)
EffNet.trainable = True
inputs = tf.keras.layers.Input(shape=((128,128) + (1,)), name = 'input_layer')
x = EffNet(inputs)
x = tf.keras.layers.GlobalAveragePooling2D(name='global_average_pooling_layer')(x)
outputs = tf.keras.layers.Dense(4, activation = 'softmax', name='output_layer')(x)
model = tf.keras.Model(inputs, outputs)
Learning_Rate = 0.01
model.compile(loss='categorical_crossentropy', optimizer = tf.keras.optimizers.Adam(learning_rate = Learning_Rate), metrics=['accuracy'])
model.summary()

#Training the Model
graphs = model.fit(train_data, validation_data = test_data, epochs = 10, verbose = False)
pd.DataFrame(graphs.history).plot(figsize=(8,6))

#check the performance
model.evaluate(test_data)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, None, None, 3) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 3), dtype=tf.float32, name='input_5'), name='input_5', description="created by layer 'input_5'"), but it was called on an input with incompatible shape (None, 128, 128, 1).
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 128, 128, 1)]     0
#
#  efficientnetb0 (Functional)  (None, None, None, 1280)  4049571
#
#  global_average_pooling_laye  (None, 1280)             0
#  r (GlobalAveragePooling2D)
#
#  output_layer (Dense)        (None, 4)                 5124
#
# =================================================================
# Total params: 4,054,695
# Trainable params: 4,012,672
# Non-trainable params: 42,023
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, None, 3) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 3), dtype=tf.float32, name='input_5'), name='input_5', description="created by layer 'input_5'"), but it was called on an input with incompatible shape (None, 128, 128, 1).
# WARNING:tensorflow:Model was constructed with shape (None, None, None, 3) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 3), dtype=tf.float32, name='input_5'), name='input_5', description="created by layer 'input_5'"), but it was called on an input with incompatible shape (None, 128, 128, 1).
# WARNING:tensorflow:Model was constructed with shape (None, None, None, 3) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 3), dtype=tf.float32, name='input_5'), name='input_5', description="created by layer 'input_5'"), but it was called on an input with incompatible shape (None, 128, 128, 1).
# 40/40 [==============================] - 13s 314ms/step - loss: 0.4405 - accuracy: 0.8547
# [0.44051605463027954, 0.854687511920929]

# %% [markdown]
# The accuracy drops significantly to 58% with learning rate of 0.1 and 85% with learning rate of 0.01.
#
#  The reason for having low accuracy may be the issue that the shape of the given data input is 128x128 rather than 224x224, which is the input that is expected for EfficientNetB0.
#
# So, in below, We will resize the image and try running CNN again with the changed size.

# %%
training_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    directory,
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="grayscale",
    batch_size=32,
    image_size=(224, 224),
    shuffle=True,
    seed=123,
    validation_split=0.2,
    subset="training",
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=True
)

testing_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    directory,
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="grayscale",
    batch_size=32,
    image_size=(224, 224),
    shuffle=True,
    seed=123,
    validation_split=0.2,
    subset="validation",
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=True
)
# Out:
# Found 6400 files belonging to 4 classes.
# Using 5120 files for training.
# Found 6400 files belonging to 4 classes.
# Using 1280 files for validation.

# %%
#Model setup
EffNet = tf.keras.applications.EfficientNetB0(include_top = False)
EffNet.trainable = True
inputs = tf.keras.layers.Input(shape=((224,224) + (1,)), name = 'input_layer')
x = EffNet(inputs)
x = tf.keras.layers.GlobalAveragePooling2D(name='global_average_pooling_layer')(x)
outputs = tf.keras.layers.Dense(4, activation = 'softmax', name='output_layer')(x)
model = tf.keras.Model(inputs, outputs)
Learning_Rate = 0.01
model.compile(loss='categorical_crossentropy', optimizer = tf.keras.optimizers.Adam(learning_rate = Learning_Rate), metrics=['accuracy'])
model.summary()

#Training the Model
graphs = model.fit(training_dataset, validation_data = testing_dataset, epochs = 10, verbose = False)
pd.DataFrame(graphs.history).plot(figsize=(8,6))

#check the performance
model.evaluate(testing_dataset)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, None, None, 3) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 3), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'"), but it was called on an input with incompatible shape (None, 224, 224, 1).
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 224, 224, 1)]     0
#
#  efficientnetb0 (Functional)  (None, None, None, 1280)  4049571
#
#  global_average_pooling_laye  (None, 1280)             0
#  r (GlobalAveragePooling2D)
#
#  output_layer (Dense)        (None, 4)                 5124
#
# =================================================================
# Total params: 4,054,695
# Trainable params: 4,012,672
# Non-trainable params: 42,023
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, None, None, 3) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 3), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'"), but it was called on an input with incompatible shape (None, 224, 224, 1).
# WARNING:tensorflow:Model was constructed with shape (None, None, None, 3) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 3), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'"), but it was called on an input with incompatible shape (None, 224, 224, 1).
# WARNING:tensorflow:Model was constructed with shape (None, None, None, 3) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, None, 3), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'"), but it was called on an input with incompatible shape (None, 224, 224, 1).
# 40/40 [==============================] - 29s 734ms/step - loss: 0.7450 - accuracy: 0.8352
# [0.744975745677948, 0.835156261920929]

# %% [markdown]
# # 2. Inception V3

# %% [markdown]
# ### Importing the necessary libraries

# %%
# !pip install tensorflow-addons
# Out:
# ['Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.10/dist-packages (0.23.0)',
#  'Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (24.0)',
#  'Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (2.13.3)']

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

import os
from distutils.dir_util import copy_tree, remove_tree

from PIL import Image
from random import randint

from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.metrics import matthews_corrcoef as MCC
from sklearn.metrics import balanced_accuracy_score as BAS
from sklearn.metrics import classification_report, confusion_matrix

import tensorflow_addons as tfa
from keras.utils.vis_utils import plot_model
from tensorflow.keras import Sequential, Input
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import Conv2D, Flatten
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing.image import ImageDataGenerator as IDG
from tensorflow.keras.layers import SeparableConv2D, BatchNormalization, GlobalAveragePooling2D

# %% [markdown]
# ### Data Pre-Processing

# %%
base_dir = "/content/drive/MyDrive/P-II/Alzheimer_s Dataset"
root_dir = "./"
test_dir = base_dir + "test/"
train_dir = base_dir + "train/"
work_dir = root_dir + "dataset/"


print(work_dir)
# Out:
# Working Directory Contents: ['ModerateDemented', 'MildDemented', 'NonDemented', 'VeryMildDemented']

# %%
WORK_DIR = './dataset/'

CLASSES = [ 'NonDemented',
            'VeryMildDemented',
            'MildDemented',
            'ModerateDemented']

IMG_SIZE = 176
IMAGE_SIZE = [176, 176]
DIM = (IMG_SIZE, IMG_SIZE)

# %%
#Performing Image Augmentation to have more data samples

ZOOM = [.99, 1.01]
BRIGHT_RANGE = [0.8, 1.2]
HORZ_FLIP = True
FILL_MODE = "constant"
DATA_FORMAT = "channels_last"

work_dr = IDG(rescale = 1./255, brightness_range=BRIGHT_RANGE, zoom_range=ZOOM, data_format=DATA_FORMAT, fill_mode=FILL_MODE, horizontal_flip=HORZ_FLIP)

train_data_gen = work_dr.flow_from_directory(directory=WORK_DIR, target_size=DIM, batch_size=6500, shuffle=False)
# Out:
# Found 6400 images belonging to 4 classes.

# %%
def show_images(generator,y_pred=None):
    """
    Input: An image generator,predicted labels (optional)
    Output: Displays a grid of 9 images with lables
    """

    # get image lables
    labels =dict(zip([0,1,2,3], CLASSES))

    # get a batch of images
    x,y = generator.next()

    # display a grid of 9 images
    plt.figure(figsize=(10, 10))
    if y_pred is None:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            idx = randint(0, 6400)
            plt.imshow(x[idx])
            plt.axis("off")
            plt.title("Class:{}".format(labels[np.argmax(y[idx])]))

    else:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            plt.imshow(x[i])
            plt.axis("off")
            plt.title("Actual:{} \nPredicted:{}".format(labels[np.argmax(y[i])],labels[y_pred[i]]))

# Display Train Images
show_images(train_data_gen)

# %%
#Retrieving the data from the ImageDataGenerator iterator

train_data, train_labels = train_data_gen.next()

# %%
#Getting to know the dimensions of our dataset

print(train_data.shape, train_labels.shape)
# Out:
# (6400, 176, 176, 3) (6400, 4)

# %%
#Performing over-sampling of the data, since the classes are imbalanced

sm = SMOTE(random_state=42)

train_data, train_labels = sm.fit_resample(train_data.reshape(-1, IMG_SIZE * IMG_SIZE * 3), train_labels)

train_data = train_data.reshape(-1, IMG_SIZE, IMG_SIZE, 3)

print(train_data.shape, train_labels.shape)
# Out:
# (12800, 176, 176, 3) (12800, 4)
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py:72: FutureWarning: Pass classes=[0 1 2 3] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)

# %%
#Splitting the data into train, test, and validation sets

train_data, test_data, train_labels, test_labels = train_test_split(train_data, train_labels, test_size = 0.2, random_state=42)
train_data, val_data, train_labels, val_labels = train_test_split(train_data, train_labels, test_size = 0.2, random_state=42)

# %% [markdown]
# ### Using the InceptionV3 model as a base model for the task

# %%
inception_model = InceptionV3(input_shape=(176, 176, 3), include_top=False, weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step

# %%
for layer in inception_model.layers:
    layer.trainable=False

# %%
custom_inception_model = Sequential([
        inception_model,
        Dropout(0.5),
        GlobalAveragePooling2D(),
        Flatten(),
        BatchNormalization(),
        Dense(512, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(256, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(64, activation='relu'),
        Dropout(0.5),
        BatchNormalization(),
        Dense(4, activation='softmax')
    ], name = "inception_cnn_model")

# %%
#Defining a custom callback function to stop training our model when accuracy goes above 99%

class MyCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if logs.get('acc') > 0.99:
            print("\nReached accuracy threshold! Terminating training.")
            self.model.stop_training = True

my_callback = MyCallback()

#ReduceLROnPlateau to stabilize the training process of the model
rop_callback = ReduceLROnPlateau(monitor="val_loss", patience=3)

# %%
METRICS = [tf.keras.metrics.CategoricalAccuracy(name='acc'),
           tf.keras.metrics.AUC(name='auc'),
           tfa.metrics.F1Score(num_classes=4)]

CALLBACKS = [my_callback, rop_callback]

custom_inception_model.compile(optimizer='rmsprop',
                              loss=tf.losses.CategoricalCrossentropy(),
                              metrics=METRICS)

custom_inception_model.summary()
# Out:
# Model: "inception_cnn_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 4, 4, 2048)        21802784
# _________________________________________________________________
# dropout (Dropout)            (None, 4, 4, 2048)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# batch_normalization_94 (Batc (None, 2048)              8192
# _________________________________________________________________
# dense (Dense)                (None, 512)               1049088
# _________________________________________________________________
# batch_normalization_95 (Batc (None, 512)               2048
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_96 (Batc (None, 256)               1024
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_97 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# batch_normalization_98 (Batc (None, 64)                256
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 23,036,644
# Trainable params: 1,227,844
# Non-trainable params: 21,808,800
# _________________________________________________________________

# %%
#Fit the training data to the model and validate it using the validation data
EPOCHS = 100

history = custom_inception_model.fit(train_data, train_labels, validation_data=(val_data, val_labels), callbacks=CALLBACKS, epochs=EPOCHS)
# Out:
# Epoch 1/100
# 256/256 [==============================] - 24s 60ms/step - loss: 1.6493 - acc: 0.3296 - auc: 0.5877 - f1_score: 0.3278 - val_loss: 0.8413 - val_acc: 0.5996 - val_auc: 0.8676 - val_f1_score: 0.5811
# Epoch 2/100
# 256/256 [==============================] - 13s 50ms/step - loss: 1.0098 - acc: 0.5470 - auc: 0.8160 - f1_score: 0.5384 - val_loss: 0.6637 - val_acc: 0.6807 - val_auc: 0.9172 - val_f1_score: 0.6512
# Epoch 3/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.8284 - acc: 0.6199 - auc: 0.8733 - f1_score: 0.6153 - val_loss: 0.6251 - val_acc: 0.7041 - val_auc: 0.9254 - val_f1_score: 0.6895
# Epoch 4/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.7475 - acc: 0.6616 - auc: 0.8985 - f1_score: 0.6547 - val_loss: 0.5988 - val_acc: 0.7271 - val_auc: 0.9328 - val_f1_score: 0.7181
# Epoch 5/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.6850 - acc: 0.7001 - auc: 0.9157 - f1_score: 0.6964 - val_loss: 0.5655 - val_acc: 0.7427 - val_auc: 0.9414 - val_f1_score: 0.7421
# Epoch 6/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.6500 - acc: 0.7145 - auc: 0.9237 - f1_score: 0.7130 - val_loss: 0.5437 - val_acc: 0.7603 - val_auc: 0.9455 - val_f1_score: 0.7592
# Epoch 7/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.6139 - acc: 0.7313 - auc: 0.9316 - f1_score: 0.7312 - val_loss: 0.5274 - val_acc: 0.7734 - val_auc: 0.9491 - val_f1_score: 0.7679
# Epoch 8/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.6170 - acc: 0.7333 - auc: 0.9320 - f1_score: 0.7344 - val_loss: 0.4917 - val_acc: 0.7817 - val_auc: 0.9549 - val_f1_score: 0.7782
# Epoch 9/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.5568 - acc: 0.7630 - auc: 0.9445 - f1_score: 0.7607 - val_loss: 0.4564 - val_acc: 0.8013 - val_auc: 0.9624 - val_f1_score: 0.7988
# Epoch 10/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.5405 - acc: 0.7712 - auc: 0.9480 - f1_score: 0.7728 - val_loss: 0.4361 - val_acc: 0.8159 - val_auc: 0.9651 - val_f1_score: 0.8126
# Epoch 11/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.5313 - acc: 0.7855 - auc: 0.9499 - f1_score: 0.7853 - val_loss: 0.4419 - val_acc: 0.8115 - val_auc: 0.9640 - val_f1_score: 0.8066
# Epoch 12/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.5102 - acc: 0.7998 - auc: 0.9546 - f1_score: 0.7973 - val_loss: 0.4117 - val_acc: 0.8262 - val_auc: 0.9687 - val_f1_score: 0.8247
# Epoch 13/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.4615 - acc: 0.8182 - auc: 0.9623 - f1_score: 0.8161 - val_loss: 0.3913 - val_acc: 0.8374 - val_auc: 0.9719 - val_f1_score: 0.8362
# Epoch 14/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.4613 - acc: 0.8226 - auc: 0.9621 - f1_score: 0.8236 - val_loss: 0.3913 - val_acc: 0.8306 - val_auc: 0.9716 - val_f1_score: 0.8284
# Epoch 15/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.4391 - acc: 0.8305 - auc: 0.9654 - f1_score: 0.8273 - val_loss: 0.3682 - val_acc: 0.8433 - val_auc: 0.9750 - val_f1_score: 0.8418
# Epoch 16/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.4195 - acc: 0.8348 - auc: 0.9683 - f1_score: 0.8327 - val_loss: 0.3646 - val_acc: 0.8506 - val_auc: 0.9757 - val_f1_score: 0.8486
# Epoch 17/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.3935 - acc: 0.8481 - auc: 0.9722 - f1_score: 0.8482 - val_loss: 0.3790 - val_acc: 0.8403 - val_auc: 0.9744 - val_f1_score: 0.8373
# Epoch 18/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.3972 - acc: 0.8498 - auc: 0.9714 - f1_score: 0.8489 - val_loss: 0.3660 - val_acc: 0.8535 - val_auc: 0.9756 - val_f1_score: 0.8523
# Epoch 19/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.3576 - acc: 0.8678 - auc: 0.9768 - f1_score: 0.8686 - val_loss: 0.3576 - val_acc: 0.8574 - val_auc: 0.9772 - val_f1_score: 0.8558
# Epoch 20/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.3608 - acc: 0.8651 - auc: 0.9765 - f1_score: 0.8644 - val_loss: 0.3427 - val_acc: 0.8564 - val_auc: 0.9787 - val_f1_score: 0.8545
# Epoch 21/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.3361 - acc: 0.8780 - auc: 0.9789 - f1_score: 0.8781 - val_loss: 0.3342 - val_acc: 0.8613 - val_auc: 0.9795 - val_f1_score: 0.8602
# Epoch 22/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.3411 - acc: 0.8660 - auc: 0.9789 - f1_score: 0.8658 - val_loss: 0.3215 - val_acc: 0.8726 - val_auc: 0.9811 - val_f1_score: 0.8712
# Epoch 23/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.3182 - acc: 0.8846 - auc: 0.9812 - f1_score: 0.8846 - val_loss: 0.3362 - val_acc: 0.8662 - val_auc: 0.9800 - val_f1_score: 0.8651
# Epoch 24/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.3278 - acc: 0.8772 - auc: 0.9801 - f1_score: 0.8775 - val_loss: 0.3342 - val_acc: 0.8662 - val_auc: 0.9793 - val_f1_score: 0.8648
# Epoch 25/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.3275 - acc: 0.8852 - auc: 0.9799 - f1_score: 0.8835 - val_loss: 0.3317 - val_acc: 0.8726 - val_auc: 0.9803 - val_f1_score: 0.8710
# Epoch 26/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.3012 - acc: 0.8935 - auc: 0.9831 - f1_score: 0.8935 - val_loss: 0.3214 - val_acc: 0.8701 - val_auc: 0.9813 - val_f1_score: 0.8689
# Epoch 27/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2714 - acc: 0.9020 - auc: 0.9863 - f1_score: 0.9020 - val_loss: 0.3151 - val_acc: 0.8740 - val_auc: 0.9821 - val_f1_score: 0.8729
# Epoch 28/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2792 - acc: 0.8982 - auc: 0.9852 - f1_score: 0.8978 - val_loss: 0.3124 - val_acc: 0.8784 - val_auc: 0.9827 - val_f1_score: 0.8773
# Epoch 29/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2687 - acc: 0.9060 - auc: 0.9862 - f1_score: 0.9053 - val_loss: 0.3115 - val_acc: 0.8784 - val_auc: 0.9830 - val_f1_score: 0.8771
# Epoch 30/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2594 - acc: 0.9068 - auc: 0.9873 - f1_score: 0.9059 - val_loss: 0.3111 - val_acc: 0.8779 - val_auc: 0.9832 - val_f1_score: 0.8767
# Epoch 31/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2572 - acc: 0.9092 - auc: 0.9873 - f1_score: 0.9098 - val_loss: 0.3092 - val_acc: 0.8818 - val_auc: 0.9832 - val_f1_score: 0.8807
# Epoch 32/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2428 - acc: 0.9144 - auc: 0.9884 - f1_score: 0.9147 - val_loss: 0.3078 - val_acc: 0.8848 - val_auc: 0.9836 - val_f1_score: 0.8839
# Epoch 33/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2388 - acc: 0.9151 - auc: 0.9886 - f1_score: 0.9134 - val_loss: 0.3084 - val_acc: 0.8799 - val_auc: 0.9836 - val_f1_score: 0.8788
# Epoch 34/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2272 - acc: 0.9228 - auc: 0.9895 - f1_score: 0.9224 - val_loss: 0.3073 - val_acc: 0.8828 - val_auc: 0.9839 - val_f1_score: 0.8819
# Epoch 35/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2337 - acc: 0.9178 - auc: 0.9892 - f1_score: 0.9170 - val_loss: 0.3091 - val_acc: 0.8838 - val_auc: 0.9837 - val_f1_score: 0.8827
# Epoch 36/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2184 - acc: 0.9234 - auc: 0.9908 - f1_score: 0.9229 - val_loss: 0.3066 - val_acc: 0.8843 - val_auc: 0.9841 - val_f1_score: 0.8832
# Epoch 37/100
# 256/256 [==============================] - 13s 49ms/step - loss: 0.2207 - acc: 0.9283 - auc: 0.9899 - f1_score: 0.9277 - val_loss: 0.3090 - val_acc: 0.8872 - val_auc: 0.9837 - val_f1_score: 0.8863
# Epoch 38/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2178 - acc: 0.9241 - auc: 0.9904 - f1_score: 0.9235 - val_loss: 0.3055 - val_acc: 0.8823 - val_auc: 0.9841 - val_f1_score: 0.8813
# Epoch 39/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2140 - acc: 0.9294 - auc: 0.9905 - f1_score: 0.9292 - val_loss: 0.3016 - val_acc: 0.8882 - val_auc: 0.9846 - val_f1_score: 0.8872
# Epoch 40/100
# 256/256 [==============================] - 13s 49ms/step - loss: 0.2225 - acc: 0.9269 - auc: 0.9896 - f1_score: 0.9259 - val_loss: 0.3026 - val_acc: 0.8857 - val_auc: 0.9846 - val_f1_score: 0.8848
# Epoch 41/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2184 - acc: 0.9267 - auc: 0.9903 - f1_score: 0.9262 - val_loss: 0.3054 - val_acc: 0.8882 - val_auc: 0.9845 - val_f1_score: 0.8874
# Epoch 42/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2433 - acc: 0.9157 - auc: 0.9881 - f1_score: 0.9157 - val_loss: 0.3033 - val_acc: 0.8867 - val_auc: 0.9846 - val_f1_score: 0.8859
# Epoch 43/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2112 - acc: 0.9293 - auc: 0.9901 - f1_score: 0.9290 - val_loss: 0.3042 - val_acc: 0.8906 - val_auc: 0.9846 - val_f1_score: 0.8900
# Epoch 44/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2202 - acc: 0.9209 - auc: 0.9903 - f1_score: 0.9204 - val_loss: 0.3031 - val_acc: 0.8887 - val_auc: 0.9846 - val_f1_score: 0.8880
# Epoch 45/100
# 256/256 [==============================] - 13s 49ms/step - loss: 0.2096 - acc: 0.9315 - auc: 0.9905 - f1_score: 0.9313 - val_loss: 0.3036 - val_acc: 0.8896 - val_auc: 0.9847 - val_f1_score: 0.8889
# Epoch 46/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2059 - acc: 0.9326 - auc: 0.9910 - f1_score: 0.9321 - val_loss: 0.3029 - val_acc: 0.8887 - val_auc: 0.9846 - val_f1_score: 0.8879
# Epoch 47/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2212 - acc: 0.9232 - auc: 0.9901 - f1_score: 0.9225 - val_loss: 0.3039 - val_acc: 0.8901 - val_auc: 0.9847 - val_f1_score: 0.8894
# Epoch 48/100
# 256/256 [==============================] - 13s 49ms/step - loss: 0.2258 - acc: 0.9231 - auc: 0.9897 - f1_score: 0.9225 - val_loss: 0.3041 - val_acc: 0.8882 - val_auc: 0.9846 - val_f1_score: 0.8874
# Epoch 49/100
# 256/256 [==============================] - 13s 51ms/step - loss: 0.2146 - acc: 0.9309 - auc: 0.9900 - f1_score: 0.9309 - val_loss: 0.3029 - val_acc: 0.8901 - val_auc: 0.9847 - val_f1_score: 0.8894
# Epoch 50/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.1876 - acc: 0.9331 - auc: 0.9928 - f1_score: 0.9326 - val_loss: 0.3052 - val_acc: 0.8887 - val_auc: 0.9846 - val_f1_score: 0.8879
# Epoch 51/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.1998 - acc: 0.9330 - auc: 0.9918 - f1_score: 0.9330 - val_loss: 0.3029 - val_acc: 0.8896 - val_auc: 0.9846 - val_f1_score: 0.8889
# Epoch 52/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2297 - acc: 0.9214 - auc: 0.9892 - f1_score: 0.9206 - val_loss: 0.3061 - val_acc: 0.8887 - val_auc: 0.9844 - val_f1_score: 0.8879
# Epoch 53/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2158 - acc: 0.9286 - auc: 0.9904 - f1_score: 0.9283 - val_loss: 0.3042 - val_acc: 0.8906 - val_auc: 0.9847 - val_f1_score: 0.8899
# Epoch 54/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2035 - acc: 0.9281 - auc: 0.9916 - f1_score: 0.9282 - val_loss: 0.3023 - val_acc: 0.8887 - val_auc: 0.9847 - val_f1_score: 0.8879
# Epoch 55/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2211 - acc: 0.9261 - auc: 0.9897 - f1_score: 0.9251 - val_loss: 0.3035 - val_acc: 0.8892 - val_auc: 0.9846 - val_f1_score: 0.8884
# Epoch 56/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2124 - acc: 0.9254 - auc: 0.9906 - f1_score: 0.9251 - val_loss: 0.3027 - val_acc: 0.8887 - val_auc: 0.9850 - val_f1_score: 0.8879
# Epoch 57/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2000 - acc: 0.9304 - auc: 0.9918 - f1_score: 0.9300 - val_loss: 0.3017 - val_acc: 0.8901 - val_auc: 0.9847 - val_f1_score: 0.8894
# Epoch 58/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2156 - acc: 0.9285 - auc: 0.9904 - f1_score: 0.9283 - val_loss: 0.3038 - val_acc: 0.8896 - val_auc: 0.9848 - val_f1_score: 0.8889
# Epoch 59/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2225 - acc: 0.9293 - auc: 0.9897 - f1_score: 0.9296 - val_loss: 0.3030 - val_acc: 0.8901 - val_auc: 0.9845 - val_f1_score: 0.8893
# Epoch 60/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2044 - acc: 0.9273 - auc: 0.9913 - f1_score: 0.9272 - val_loss: 0.3024 - val_acc: 0.8906 - val_auc: 0.9847 - val_f1_score: 0.8899
# Epoch 61/100
# 256/256 [==============================] - 13s 49ms/step - loss: 0.2209 - acc: 0.9250 - auc: 0.9895 - f1_score: 0.9249 - val_loss: 0.3040 - val_acc: 0.8911 - val_auc: 0.9846 - val_f1_score: 0.8904
# Epoch 62/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2021 - acc: 0.9319 - auc: 0.9912 - f1_score: 0.9317 - val_loss: 0.3036 - val_acc: 0.8887 - val_auc: 0.9847 - val_f1_score: 0.8880
# Epoch 63/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2265 - acc: 0.9232 - auc: 0.9897 - f1_score: 0.9226 - val_loss: 0.3045 - val_acc: 0.8872 - val_auc: 0.9847 - val_f1_score: 0.8864
# Epoch 64/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2200 - acc: 0.9280 - auc: 0.9897 - f1_score: 0.9279 - val_loss: 0.3033 - val_acc: 0.8896 - val_auc: 0.9847 - val_f1_score: 0.8889
# Epoch 65/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2126 - acc: 0.9286 - auc: 0.9904 - f1_score: 0.9280 - val_loss: 0.3050 - val_acc: 0.8901 - val_auc: 0.9847 - val_f1_score: 0.8894
# Epoch 66/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2097 - acc: 0.9288 - auc: 0.9908 - f1_score: 0.9287 - val_loss: 0.3028 - val_acc: 0.8896 - val_auc: 0.9846 - val_f1_score: 0.8890
# Epoch 67/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2266 - acc: 0.9233 - auc: 0.9892 - f1_score: 0.9232 - val_loss: 0.3032 - val_acc: 0.8916 - val_auc: 0.9846 - val_f1_score: 0.8909
# Epoch 68/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2120 - acc: 0.9280 - auc: 0.9906 - f1_score: 0.9278 - val_loss: 0.3018 - val_acc: 0.8906 - val_auc: 0.9849 - val_f1_score: 0.8899
# Epoch 69/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2173 - acc: 0.9235 - auc: 0.9903 - f1_score: 0.9239 - val_loss: 0.3034 - val_acc: 0.8896 - val_auc: 0.9848 - val_f1_score: 0.8890
# Epoch 70/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2087 - acc: 0.9242 - auc: 0.9912 - f1_score: 0.9241 - val_loss: 0.3037 - val_acc: 0.8896 - val_auc: 0.9847 - val_f1_score: 0.8889
# Epoch 71/100
# 256/256 [==============================] - 13s 49ms/step - loss: 0.2184 - acc: 0.9251 - auc: 0.9901 - f1_score: 0.9256 - val_loss: 0.3046 - val_acc: 0.8911 - val_auc: 0.9845 - val_f1_score: 0.8903
# Epoch 72/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2020 - acc: 0.9347 - auc: 0.9913 - f1_score: 0.9345 - val_loss: 0.3045 - val_acc: 0.8877 - val_auc: 0.9846 - val_f1_score: 0.8869
# Epoch 73/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2245 - acc: 0.9246 - auc: 0.9894 - f1_score: 0.9239 - val_loss: 0.3049 - val_acc: 0.8887 - val_auc: 0.9845 - val_f1_score: 0.8879
# Epoch 74/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2176 - acc: 0.9287 - auc: 0.9896 - f1_score: 0.9285 - val_loss: 0.3032 - val_acc: 0.8896 - val_auc: 0.9847 - val_f1_score: 0.8889
# Epoch 75/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2265 - acc: 0.9239 - auc: 0.9892 - f1_score: 0.9237 - val_loss: 0.3022 - val_acc: 0.8911 - val_auc: 0.9847 - val_f1_score: 0.8904
# Epoch 76/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2174 - acc: 0.9320 - auc: 0.9902 - f1_score: 0.9316 - val_loss: 0.3042 - val_acc: 0.8882 - val_auc: 0.9845 - val_f1_score: 0.8873
# Epoch 77/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2150 - acc: 0.9254 - auc: 0.9905 - f1_score: 0.9249 - val_loss: 0.3035 - val_acc: 0.8906 - val_auc: 0.9845 - val_f1_score: 0.8898
# Epoch 78/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2225 - acc: 0.9222 - auc: 0.9899 - f1_score: 0.9223 - val_loss: 0.3051 - val_acc: 0.8906 - val_auc: 0.9844 - val_f1_score: 0.8898
# Epoch 79/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2009 - acc: 0.9295 - auc: 0.9913 - f1_score: 0.9289 - val_loss: 0.3059 - val_acc: 0.8901 - val_auc: 0.9845 - val_f1_score: 0.8894
# Epoch 80/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2120 - acc: 0.9313 - auc: 0.9904 - f1_score: 0.9314 - val_loss: 0.3030 - val_acc: 0.8892 - val_auc: 0.9848 - val_f1_score: 0.8884
# Epoch 81/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2202 - acc: 0.9258 - auc: 0.9901 - f1_score: 0.9263 - val_loss: 0.3022 - val_acc: 0.8892 - val_auc: 0.9849 - val_f1_score: 0.8884
# Epoch 82/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2222 - acc: 0.9200 - auc: 0.9898 - f1_score: 0.9199 - val_loss: 0.3038 - val_acc: 0.8882 - val_auc: 0.9844 - val_f1_score: 0.8874
# Epoch 83/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2019 - acc: 0.9305 - auc: 0.9916 - f1_score: 0.9304 - val_loss: 0.3046 - val_acc: 0.8906 - val_auc: 0.9846 - val_f1_score: 0.8899
# Epoch 84/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2157 - acc: 0.9302 - auc: 0.9899 - f1_score: 0.9302 - val_loss: 0.3028 - val_acc: 0.8901 - val_auc: 0.9847 - val_f1_score: 0.8894
# Epoch 85/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2056 - acc: 0.9316 - auc: 0.9914 - f1_score: 0.9313 - val_loss: 0.3023 - val_acc: 0.8906 - val_auc: 0.9847 - val_f1_score: 0.8899
# Epoch 86/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2191 - acc: 0.9265 - auc: 0.9902 - f1_score: 0.9275 - val_loss: 0.3034 - val_acc: 0.8892 - val_auc: 0.9848 - val_f1_score: 0.8886
# Epoch 87/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2355 - acc: 0.9202 - auc: 0.9885 - f1_score: 0.9203 - val_loss: 0.3041 - val_acc: 0.8901 - val_auc: 0.9847 - val_f1_score: 0.8894
# Epoch 88/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.1997 - acc: 0.9353 - auc: 0.9915 - f1_score: 0.9354 - val_loss: 0.3045 - val_acc: 0.8877 - val_auc: 0.9847 - val_f1_score: 0.8869
# Epoch 89/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2097 - acc: 0.9257 - auc: 0.9910 - f1_score: 0.9254 - val_loss: 0.3049 - val_acc: 0.8882 - val_auc: 0.9846 - val_f1_score: 0.8874
# Epoch 90/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2211 - acc: 0.9267 - auc: 0.9896 - f1_score: 0.9270 - val_loss: 0.3045 - val_acc: 0.8901 - val_auc: 0.9847 - val_f1_score: 0.8894
# Epoch 91/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2014 - acc: 0.9312 - auc: 0.9911 - f1_score: 0.9304 - val_loss: 0.3036 - val_acc: 0.8887 - val_auc: 0.9847 - val_f1_score: 0.8879
# Epoch 92/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2144 - acc: 0.9304 - auc: 0.9903 - f1_score: 0.9297 - val_loss: 0.3041 - val_acc: 0.8887 - val_auc: 0.9847 - val_f1_score: 0.8879
# Epoch 93/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2077 - acc: 0.9260 - auc: 0.9914 - f1_score: 0.9259 - val_loss: 0.3037 - val_acc: 0.8896 - val_auc: 0.9846 - val_f1_score: 0.8890
# Epoch 94/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2116 - acc: 0.9273 - auc: 0.9910 - f1_score: 0.9272 - val_loss: 0.3050 - val_acc: 0.8887 - val_auc: 0.9847 - val_f1_score: 0.8879
# Epoch 95/100
# 256/256 [==============================] - 13s 49ms/step - loss: 0.2165 - acc: 0.9271 - auc: 0.9900 - f1_score: 0.9273 - val_loss: 0.3049 - val_acc: 0.8896 - val_auc: 0.9844 - val_f1_score: 0.8889
# Epoch 96/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2182 - acc: 0.9249 - auc: 0.9905 - f1_score: 0.9243 - val_loss: 0.3041 - val_acc: 0.8916 - val_auc: 0.9846 - val_f1_score: 0.8909
# Epoch 97/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2027 - acc: 0.9302 - auc: 0.9915 - f1_score: 0.9296 - val_loss: 0.3056 - val_acc: 0.8887 - val_auc: 0.9846 - val_f1_score: 0.8879
# Epoch 98/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2030 - acc: 0.9337 - auc: 0.9915 - f1_score: 0.9333 - val_loss: 0.3046 - val_acc: 0.8887 - val_auc: 0.9846 - val_f1_score: 0.8879
# Epoch 99/100
# 256/256 [==============================] - 13s 50ms/step - loss: 0.2031 - acc: 0.9328 - auc: 0.9917 - f1_score: 0.9321 - val_loss: 0.3045 - val_acc: 0.8896 - val_auc: 0.9845 - val_f1_score: 0.8889
# Epoch 100/100
# 256/256 [==============================] - 13s 49ms/step - loss: 0.2117 - acc: 0.9226 - auc: 0.9911 - f1_score: 0.9230 - val_loss: 0.3057 - val_acc: 0.8896 - val_auc: 0.9844 - val_f1_score: 0.8889

# %% [markdown]
# ### Tabulating the Results of our custom InceptionV3 model

# %%
#Plotting the trend of the metrics during training

fig, ax = plt.subplots(1, 3, figsize = (30, 5))
ax = ax.ravel()

for i, metric in enumerate(["acc", "auc", "loss"]):
    ax[i].plot(history.history[metric])
    ax[i].plot(history.history["val_" + metric])
    ax[i].set_title("Model {}".format(metric))
    ax[i].set_xlabel("Epochs")
    ax[i].set_ylabel(metric)
    ax[i].legend(["train", "val"])

# %%
#Evaluating the model on the data

#train_scores = model.evaluate(train_data, train_labels)
#val_scores = model.evaluate(val_data, val_labels)
test_scores = custom_inception_model.evaluate(test_data, test_labels)

#print("Training Accuracy: %.2f%%"%(train_scores[1] * 100))
#print("Validation Accuracy: %.2f%%"%(val_scores[1] * 100))
print("Testing Accuracy: %.2f%%"%(test_scores[1] * 100))
# Out:
# 80/80 [==============================] - 3s 38ms/step - loss: 0.2944 - acc: 0.8906 - auc: 0.9854 - f1_score: 0.8909
# Testing Accuracy: 89.06%

# %%
#Predicting the test data

pred_labels = custom_inception_model.predict(test_data)

# %%
#Print the classification report of the tested data

#Since the labels are softmax arrays, we need to roundoff to have it in the form of 0s and 1s,
#similar to the test_labels
def roundoff(arr):
    """To round off according to the argmax of each predicted label array. """
    arr[np.argwhere(arr != arr.max())] = 0
    arr[np.argwhere(arr == arr.max())] = 1
    return arr

for labels in pred_labels:
    labels = roundoff(labels)

print(classification_report(test_labels, pred_labels, target_names=CLASSES))
# Out:
#                   precision    recall  f1-score   support
#
#      NonDemented       0.94      0.95      0.94       639
# VeryMildDemented       1.00      1.00      1.00       635
#     MildDemented       0.85      0.79      0.82       662
# ModerateDemented       0.78      0.83      0.81       624
#
#        micro avg       0.89      0.89      0.89      2560
#        macro avg       0.89      0.89      0.89      2560
#     weighted avg       0.89      0.89      0.89      2560
#      samples avg       0.89      0.89      0.89      2560

# %%
#Plot the confusion matrix to understand the classification in detail

pred_ls = np.argmax(pred_labels, axis=1)
test_ls = np.argmax(test_labels, axis=1)

conf_arr = confusion_matrix(test_ls, pred_ls)

plt.figure(figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

ax = sns.heatmap(conf_arr, cmap='Greens', annot=True, fmt='d', xticklabels= CLASSES,
                yticklabels=CLASSES)

plt.title('Alzheimer\'s Disease Diagnosis')
plt.xlabel('Prediction')
plt.ylabel('Truth')
plt.show(ax)

# %%
#Printing some other classification metrics

print("Balanced Accuracy Score: {} %".format(round(BAS(test_ls, pred_ls) * 100, 2)))
print("Matthew's Correlation Coefficient: {} %".format(round(MCC(test_ls, pred_ls) * 100, 2)))
# Out:
# Balanced Accuracy Score: 89.14 %
# Matthew's Correlation Coefficient: 85.46 %

# %%
#Saving the model for future use

custom_inception_model_dir = work_dir + "alzheimer_inception_cnn_model"
custom_inception_model.save(custom_inception_model_dir, save_format='h5')
os.listdir(work_dir)
# Out:
# ['ModerateDemented',
#  'MildDemented',
#  'NonDemented',
#  'alzheimer_inception_cnn_model',
#  'VeryMildDemented']

# %% [markdown]
# ### Using a custom CNN model for the task

# %% [markdown]
# # 3. Custom CNN (Building)

# %%
import tensorflow as tf

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import keras as keras

# %%
import imblearn

# %%
from imblearn.over_sampling import SMOTE

# %%
# !pip install tensorflow-addons

# %% [markdown]
# ### Importing the necessary libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

import os
from distutils.dir_util import copy_tree, remove_tree

from PIL import Image
from random import randint

from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.metrics import matthews_corrcoef as MCC
from sklearn.metrics import balanced_accuracy_score as BAS
from sklearn.metrics import classification_report, confusion_matrix

import tensorflow_addons as tfa
from keras.utils.vis_utils import plot_model
from tensorflow.keras import Sequential, Input
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import Conv2D, Flatten
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing.image import ImageDataGenerator as IDG
from tensorflow.keras.layers import SeparableConv2D, BatchNormalization, MaxPool2D

# %% [markdown]
# ### Data Pre-Processing

# %%
import os

# %%
base_dir = "/content/drive/MyDrive/P-II/Alzheimer_s Dataset"
root_dir = "./"
test_dir = base_dir + "test/"
train_dir = base_dir + "train/"
work_dir = root_dir + "dataset/"


print(work_dir)
# Out:
# ./dataset/

# %%
WORK_DIR = './dataset/'

CLASSES = [ 'NonDemented',
            'VeryMildDemented',
            'MildDemented',
            'ModerateDemented']

IMG_SIZE = 176
IMAGE_SIZE = [176, 176]
DIM = (IMG_SIZE, IMG_SIZE)

# %%
#Performing Image Augmentation to have more data samples

ZOOM = [.99, 1.01]
BRIGHT_RANGE = [0.8, 1.2]
HORZ_FLIP = True
FILL_MODE = "constant"
DATA_FORMAT = "channels_last"

work_dr = IDG(rescale = 1./255, brightness_range=BRIGHT_RANGE, zoom_range=ZOOM, data_format=DATA_FORMAT, fill_mode=FILL_MODE, horizontal_flip=HORZ_FLIP)

train_data_gen = work_dr.flow_from_directory(directory=WORK_DIR, target_size=DIM, batch_size=6500, shuffle=False)
# Out:
# Found 6400 images belonging to 4 classes.

# %%
def show_images(generator,y_pred=None):
    """
    Input: An image generator,predicted labels (optional)
    Output: Displays a grid of 9 images with lables
    """

    # get image lables
    labels =dict(zip([0,1,2,3], CLASSES))

    # get a batch of images
    x,y = generator.next()

    # display a grid of 9 images
    plt.figure(figsize=(10, 10))
    if y_pred is None:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            idx = randint(0, 6400)
            plt.imshow(x[idx])
            plt.axis("off")
            plt.title("Class:{}".format(labels[np.argmax(y[idx])]))

    else:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            plt.imshow(x[i])
            plt.axis("off")
            plt.title("Actual:{} \nPredicted:{}".format(labels[np.argmax(y[i])],labels[y_pred[i]]))

# Display Train Images
show_images(train_data_gen)

# %%
#Retrieving the data from the ImageDataGenerator iterator

train_data, train_labels = train_data_gen.next()

# %%
#Getting to know the dimensions of our dataset

print(train_data.shape, train_labels.shape)
# Out:
# (6400, 176, 176, 3) (6400, 4)

# %%
#Performing over-sampling of the data, since the classes are imbalanced

sm = SMOTE(random_state=42)

train_data, train_labels = sm.fit_resample(train_data.reshape(-1, IMG_SIZE * IMG_SIZE * 3), train_labels)

train_data = train_data.reshape(-1, IMG_SIZE, IMG_SIZE, 3)

print(train_data.shape, train_labels.shape)
# Out:
# (12800, 176, 176, 3) (12800, 4)
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py:72: FutureWarning: Pass classes=[0 1 2 3] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)

# %%
#Splitting the data into train, test, and validation sets

train_data, test_data, train_labels, test_labels = train_test_split(train_data, train_labels, test_size = 0.2, random_state=42)
train_data, val_data, train_labels, val_labels = train_test_split(train_data, train_labels, test_size = 0.2, random_state=42)

# %% [markdown]
# ### Constructing a Convolutional Neural Network Architecture

# %%
def conv_block(filters, act='relu'):
    """Defining a Convolutional NN block for a Sequential CNN model. """

    block = Sequential()
    block.add(Conv2D(filters, 3, activation=act, padding='same'))
    block.add(Conv2D(filters, 3, activation=act, padding='same'))
    block.add(BatchNormalization())
    block.add(MaxPool2D())

    return block

# %%
def dense_block(units, dropout_rate, act='relu'):
    """Defining a Dense NN block for a Sequential CNN model. """

    block = Sequential()
    block.add(Dense(units, activation=act))
    block.add(BatchNormalization())
    block.add(Dropout(dropout_rate))

    return block

# %%
def construct_model(act='relu'):
    """Constructing a Sequential CNN architecture for performing the classification task. """

    model = Sequential([
        Input(shape=(*IMAGE_SIZE, 3)),
        Conv2D(16, 3, activation=act, padding='same'),
        Conv2D(16, 3, activation=act, padding='same'),
        MaxPool2D(),
        conv_block(32),
        conv_block(64),
        conv_block(128),
        Dropout(0.2),
        conv_block(256),
        Dropout(0.2),
        Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        Dense(4, activation='softmax')
    ], name = "cnn_model")

    return model

# %%
#Defining a custom callback function to stop training our model when accuracy goes above 99%

class MyCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if logs.get('val_acc') > 0.99:
            print("\nReached accuracy threshold! Terminating training.")
            self.model.stop_training = True

my_callback = MyCallback()

#EarlyStopping callback to make sure model is always learning
early_stopping = EarlyStopping(monitor='val_loss', patience=2)

# %%
#Defining other parameters for our CNN model

model = construct_model()

METRICS = [tf.keras.metrics.CategoricalAccuracy(name='acc'),
           tf.keras.metrics.AUC(name='auc'),
           tfa.metrics.F1Score(num_classes=4)]

CALLBACKS = [my_callback]

model.compile(optimizer='adam',
              loss=tf.losses.CategoricalCrossentropy(),
              metrics=METRICS)

model.summary()
# Out:
# Model: "cnn_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 176, 176, 16)      448
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 176, 176, 16)      2320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 88, 88, 16)        0
# _________________________________________________________________
# sequential (Sequential)      (None, 44, 44, 32)        14016
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 22, 22, 64)        55680
# _________________________________________________________________
# sequential_2 (Sequential)    (None, 11, 11, 128)       221952
# _________________________________________________________________
# dropout (Dropout)            (None, 11, 11, 128)       0
# _________________________________________________________________
# sequential_3 (Sequential)    (None, 5, 5, 256)         886272
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 5, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# sequential_4 (Sequential)    (None, 512)               3279360
# _________________________________________________________________
# sequential_5 (Sequential)    (None, 128)               66176
# _________________________________________________________________
# sequential_6 (Sequential)    (None, 64)                8512
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 4,534,996
# Trainable params: 4,532,628
# Non-trainable params: 2,368
# _________________________________________________________________

# %% [markdown]
# ### Training & Testing the Model

# %%
#Fit the training data to the model and validate it using the validation data
EPOCHS = 100

history = model.fit(train_data, train_labels, validation_data=(val_data, val_labels), callbacks=CALLBACKS, epochs=EPOCHS)
# Out:
# Epoch 1/100
# 256/256 [==============================] - 18s 45ms/step - loss: 1.8429 - acc: 0.2865 - auc: 0.5369 - f1_score: 0.2859 - val_loss: 2.1595 - val_acc: 0.2568 - val_auc: 0.5156 - val_f1_score: 0.1022
# Epoch 2/100
# 256/256 [==============================] - 9s 37ms/step - loss: 1.1636 - acc: 0.4781 - auc: 0.7535 - f1_score: 0.4667 - val_loss: 1.6218 - val_acc: 0.2500 - val_auc: 0.6387 - val_f1_score: 0.1150
# Epoch 3/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.8082 - acc: 0.6305 - auc: 0.8809 - f1_score: 0.6191 - val_loss: 3.6864 - val_acc: 0.3687 - val_auc: 0.6102 - val_f1_score: 0.2677
# Epoch 4/100
# 256/256 [==============================] - 10s 38ms/step - loss: 0.7229 - acc: 0.6640 - auc: 0.9039 - f1_score: 0.6593 - val_loss: 3.6735 - val_acc: 0.2407 - val_auc: 0.5194 - val_f1_score: 0.0983
# Epoch 5/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.6758 - acc: 0.6874 - auc: 0.9151 - f1_score: 0.6869 - val_loss: 1.9865 - val_acc: 0.2861 - val_auc: 0.6183 - val_f1_score: 0.2085
# Epoch 6/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.6085 - acc: 0.7197 - auc: 0.9310 - f1_score: 0.7161 - val_loss: 0.7537 - val_acc: 0.6602 - val_auc: 0.8967 - val_f1_score: 0.6697
# Epoch 7/100
# 256/256 [==============================] - 10s 38ms/step - loss: 0.5695 - acc: 0.7436 - auc: 0.9400 - f1_score: 0.7439 - val_loss: 1.8508 - val_acc: 0.3228 - val_auc: 0.6430 - val_f1_score: 0.2667
# Epoch 8/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.5645 - acc: 0.7407 - auc: 0.9412 - f1_score: 0.7405 - val_loss: 3.3434 - val_acc: 0.4839 - val_auc: 0.6928 - val_f1_score: 0.3624
# Epoch 9/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.5283 - acc: 0.7629 - auc: 0.9482 - f1_score: 0.7642 - val_loss: 3.3777 - val_acc: 0.2539 - val_auc: 0.5621 - val_f1_score: 0.1346
# Epoch 10/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.4765 - acc: 0.7891 - auc: 0.9578 - f1_score: 0.7909 - val_loss: 0.7077 - val_acc: 0.6904 - val_auc: 0.9151 - val_f1_score: 0.6769
# Epoch 11/100
# 256/256 [==============================] - 10s 37ms/step - loss: 0.4573 - acc: 0.7985 - auc: 0.9609 - f1_score: 0.7998 - val_loss: 0.8254 - val_acc: 0.6392 - val_auc: 0.9036 - val_f1_score: 0.5797
# Epoch 12/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.4332 - acc: 0.8082 - auc: 0.9643 - f1_score: 0.8090 - val_loss: 1.7510 - val_acc: 0.5615 - val_auc: 0.8359 - val_f1_score: 0.4883
# Epoch 13/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.4092 - acc: 0.8209 - auc: 0.9686 - f1_score: 0.8200 - val_loss: 0.4593 - val_acc: 0.7783 - val_auc: 0.9609 - val_f1_score: 0.7577
# Epoch 14/100
# 256/256 [==============================] - 10s 37ms/step - loss: 0.3958 - acc: 0.8368 - auc: 0.9711 - f1_score: 0.8356 - val_loss: 0.4629 - val_acc: 0.7998 - val_auc: 0.9615 - val_f1_score: 0.8042
# Epoch 15/100
# 256/256 [==============================] - 9s 36ms/step - loss: 0.3365 - acc: 0.8654 - auc: 0.9789 - f1_score: 0.8661 - val_loss: 2.5809 - val_acc: 0.5308 - val_auc: 0.7806 - val_f1_score: 0.4313
# Epoch 16/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.3095 - acc: 0.8707 - auc: 0.9818 - f1_score: 0.8715 - val_loss: 0.3516 - val_acc: 0.8467 - val_auc: 0.9766 - val_f1_score: 0.8450
# Epoch 17/100
# 256/256 [==============================] - 10s 37ms/step - loss: 0.2934 - acc: 0.8879 - auc: 0.9833 - f1_score: 0.8886 - val_loss: 1.1720 - val_acc: 0.6426 - val_auc: 0.8908 - val_f1_score: 0.6126
# Epoch 18/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.2491 - acc: 0.9008 - auc: 0.9882 - f1_score: 0.9003 - val_loss: 0.5145 - val_acc: 0.8037 - val_auc: 0.9640 - val_f1_score: 0.7863
# Epoch 19/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.2187 - acc: 0.9176 - auc: 0.9906 - f1_score: 0.9171 - val_loss: 1.2446 - val_acc: 0.6025 - val_auc: 0.8655 - val_f1_score: 0.5905
# Epoch 20/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.1998 - acc: 0.9287 - auc: 0.9917 - f1_score: 0.9282 - val_loss: 4.4247 - val_acc: 0.2842 - val_auc: 0.5759 - val_f1_score: 0.1814
# Epoch 21/100
# 256/256 [==============================] - 10s 38ms/step - loss: 0.1951 - acc: 0.9310 - auc: 0.9918 - f1_score: 0.9310 - val_loss: 0.9558 - val_acc: 0.7002 - val_auc: 0.9192 - val_f1_score: 0.6683
# Epoch 22/100
# 256/256 [==============================] - 9s 36ms/step - loss: 0.1382 - acc: 0.9527 - auc: 0.9963 - f1_score: 0.9530 - val_loss: 1.3842 - val_acc: 0.6226 - val_auc: 0.8672 - val_f1_score: 0.6088
# Epoch 23/100
# 256/256 [==============================] - 9s 36ms/step - loss: 0.1463 - acc: 0.9486 - auc: 0.9949 - f1_score: 0.9489 - val_loss: 0.3276 - val_acc: 0.8789 - val_auc: 0.9833 - val_f1_score: 0.8743
# Epoch 24/100
# 256/256 [==============================] - 10s 38ms/step - loss: 0.1451 - acc: 0.9465 - auc: 0.9956 - f1_score: 0.9465 - val_loss: 0.2994 - val_acc: 0.8994 - val_auc: 0.9852 - val_f1_score: 0.8992
# Epoch 25/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.1516 - acc: 0.9467 - auc: 0.9949 - f1_score: 0.9472 - val_loss: 0.3656 - val_acc: 0.8716 - val_auc: 0.9789 - val_f1_score: 0.8732
# Epoch 26/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.1101 - acc: 0.9614 - auc: 0.9970 - f1_score: 0.9611 - val_loss: 0.7265 - val_acc: 0.8037 - val_auc: 0.9570 - val_f1_score: 0.7744
# Epoch 27/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0906 - acc: 0.9717 - auc: 0.9978 - f1_score: 0.9715 - val_loss: 0.2871 - val_acc: 0.8936 - val_auc: 0.9865 - val_f1_score: 0.8917
# Epoch 28/100
# 256/256 [==============================] - 10s 38ms/step - loss: 0.0870 - acc: 0.9686 - auc: 0.9982 - f1_score: 0.9689 - val_loss: 0.5611 - val_acc: 0.8643 - val_auc: 0.9664 - val_f1_score: 0.8550
# Epoch 29/100
# 256/256 [==============================] - 9s 36ms/step - loss: 0.1107 - acc: 0.9632 - auc: 0.9967 - f1_score: 0.9631 - val_loss: 0.4654 - val_acc: 0.8540 - val_auc: 0.9739 - val_f1_score: 0.8472
# Epoch 30/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0816 - acc: 0.9747 - auc: 0.9980 - f1_score: 0.9744 - val_loss: 0.5828 - val_acc: 0.8345 - val_auc: 0.9631 - val_f1_score: 0.8265
# Epoch 31/100
# 256/256 [==============================] - 10s 37ms/step - loss: 0.0907 - acc: 0.9706 - auc: 0.9980 - f1_score: 0.9705 - val_loss: 0.2845 - val_acc: 0.9165 - val_auc: 0.9854 - val_f1_score: 0.9153
# Epoch 32/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0786 - acc: 0.9745 - auc: 0.9982 - f1_score: 0.9747 - val_loss: 0.3198 - val_acc: 0.9004 - val_auc: 0.9833 - val_f1_score: 0.8987
# Epoch 33/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0684 - acc: 0.9768 - auc: 0.9987 - f1_score: 0.9766 - val_loss: 0.9447 - val_acc: 0.7417 - val_auc: 0.9136 - val_f1_score: 0.7192
# Epoch 34/100
# 256/256 [==============================] - 10s 37ms/step - loss: 0.0909 - acc: 0.9722 - auc: 0.9971 - f1_score: 0.9719 - val_loss: 0.5462 - val_acc: 0.8579 - val_auc: 0.9637 - val_f1_score: 0.8595
# Epoch 35/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0741 - acc: 0.9780 - auc: 0.9979 - f1_score: 0.9780 - val_loss: 0.3680 - val_acc: 0.8931 - val_auc: 0.9807 - val_f1_score: 0.8893
# Epoch 36/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0661 - acc: 0.9789 - auc: 0.9986 - f1_score: 0.9787 - val_loss: 0.7937 - val_acc: 0.7920 - val_auc: 0.9412 - val_f1_score: 0.7919
# Epoch 37/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0675 - acc: 0.9801 - auc: 0.9979 - f1_score: 0.9803 - val_loss: 0.2618 - val_acc: 0.9292 - val_auc: 0.9878 - val_f1_score: 0.9293
# Epoch 38/100
# 256/256 [==============================] - 10s 38ms/step - loss: 0.0626 - acc: 0.9785 - auc: 0.9987 - f1_score: 0.9781 - val_loss: 0.7331 - val_acc: 0.8223 - val_auc: 0.9496 - val_f1_score: 0.8082
# Epoch 39/100
# 256/256 [==============================] - 9s 36ms/step - loss: 0.0539 - acc: 0.9828 - auc: 0.9985 - f1_score: 0.9828 - val_loss: 0.2103 - val_acc: 0.9395 - val_auc: 0.9888 - val_f1_score: 0.9392
# Epoch 40/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0619 - acc: 0.9782 - auc: 0.9991 - f1_score: 0.9780 - val_loss: 0.4730 - val_acc: 0.8828 - val_auc: 0.9715 - val_f1_score: 0.8777
# Epoch 41/100
# 256/256 [==============================] - 10s 38ms/step - loss: 0.0329 - acc: 0.9884 - auc: 0.9995 - f1_score: 0.9885 - val_loss: 0.5597 - val_acc: 0.8711 - val_auc: 0.9595 - val_f1_score: 0.8692
# Epoch 42/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0596 - acc: 0.9812 - auc: 0.9986 - f1_score: 0.9812 - val_loss: 0.4962 - val_acc: 0.8721 - val_auc: 0.9702 - val_f1_score: 0.8693
# Epoch 43/100
# 256/256 [==============================] - 9s 36ms/step - loss: 0.0625 - acc: 0.9791 - auc: 0.9986 - f1_score: 0.9782 - val_loss: 0.4860 - val_acc: 0.8843 - val_auc: 0.9680 - val_f1_score: 0.8849
# Epoch 44/100
# 256/256 [==============================] - 9s 36ms/step - loss: 0.0495 - acc: 0.9842 - auc: 0.9989 - f1_score: 0.9840 - val_loss: 1.2768 - val_acc: 0.7188 - val_auc: 0.8960 - val_f1_score: 0.7007
# Epoch 45/100
# 256/256 [==============================] - 10s 38ms/step - loss: 0.0530 - acc: 0.9830 - auc: 0.9988 - f1_score: 0.9830 - val_loss: 0.3423 - val_acc: 0.9033 - val_auc: 0.9821 - val_f1_score: 0.9008
# Epoch 46/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0408 - acc: 0.9852 - auc: 0.9994 - f1_score: 0.9852 - val_loss: 0.3077 - val_acc: 0.9238 - val_auc: 0.9846 - val_f1_score: 0.9227
# Epoch 47/100
# 256/256 [==============================] - 9s 36ms/step - loss: 0.0343 - acc: 0.9893 - auc: 0.9996 - f1_score: 0.9893 - val_loss: 0.2294 - val_acc: 0.9336 - val_auc: 0.9890 - val_f1_score: 0.9335
# Epoch 48/100
# 256/256 [==============================] - 10s 37ms/step - loss: 0.0399 - acc: 0.9872 - auc: 0.9995 - f1_score: 0.9873 - val_loss: 0.1915 - val_acc: 0.9536 - val_auc: 0.9888 - val_f1_score: 0.9534
# Epoch 49/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0478 - acc: 0.9826 - auc: 0.9991 - f1_score: 0.9827 - val_loss: 0.3986 - val_acc: 0.8999 - val_auc: 0.9766 - val_f1_score: 0.8975
# Epoch 50/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0395 - acc: 0.9857 - auc: 0.9993 - f1_score: 0.9856 - val_loss: 0.2440 - val_acc: 0.9385 - val_auc: 0.9886 - val_f1_score: 0.9377
# Epoch 51/100
# 256/256 [==============================] - 10s 37ms/step - loss: 0.0263 - acc: 0.9925 - auc: 0.9995 - f1_score: 0.9925 - val_loss: 0.2240 - val_acc: 0.9487 - val_auc: 0.9860 - val_f1_score: 0.9485
# Epoch 52/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0240 - acc: 0.9930 - auc: 0.9996 - f1_score: 0.9930 - val_loss: 0.2765 - val_acc: 0.9238 - val_auc: 0.9856 - val_f1_score: 0.9234
# Epoch 53/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0757 - acc: 0.9747 - auc: 0.9982 - f1_score: 0.9749 - val_loss: 0.6177 - val_acc: 0.8599 - val_auc: 0.9585 - val_f1_score: 0.8579
# Epoch 54/100
# 256/256 [==============================] - 10s 38ms/step - loss: 0.0305 - acc: 0.9896 - auc: 0.9997 - f1_score: 0.9895 - val_loss: 0.1933 - val_acc: 0.9482 - val_auc: 0.9898 - val_f1_score: 0.9479
# Epoch 55/100
# 256/256 [==============================] - 10s 38ms/step - loss: 0.0674 - acc: 0.9843 - auc: 0.9971 - f1_score: 0.9843 - val_loss: 0.1789 - val_acc: 0.9565 - val_auc: 0.9908 - val_f1_score: 0.9564
# Epoch 56/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0274 - acc: 0.9927 - auc: 0.9995 - f1_score: 0.9926 - val_loss: 0.2320 - val_acc: 0.9429 - val_auc: 0.9868 - val_f1_score: 0.9430
# Epoch 57/100
# 256/256 [==============================] - 10s 38ms/step - loss: 0.0359 - acc: 0.9875 - auc: 0.9994 - f1_score: 0.9874 - val_loss: 0.2456 - val_acc: 0.9312 - val_auc: 0.9859 - val_f1_score: 0.9315
# Epoch 58/100
# 256/256 [==============================] - 10s 38ms/step - loss: 0.0476 - acc: 0.9843 - auc: 0.9991 - f1_score: 0.9842 - val_loss: 0.3597 - val_acc: 0.9038 - val_auc: 0.9802 - val_f1_score: 0.9028
# Epoch 59/100
# 256/256 [==============================] - 10s 38ms/step - loss: 0.0281 - acc: 0.9923 - auc: 0.9992 - f1_score: 0.9923 - val_loss: 0.2233 - val_acc: 0.9424 - val_auc: 0.9878 - val_f1_score: 0.9419
# Epoch 60/100
# 256/256 [==============================] - 10s 37ms/step - loss: 0.0324 - acc: 0.9906 - auc: 0.9994 - f1_score: 0.9907 - val_loss: 0.1898 - val_acc: 0.9482 - val_auc: 0.9910 - val_f1_score: 0.9481
# Epoch 61/100
# 256/256 [==============================] - 10s 38ms/step - loss: 0.0274 - acc: 0.9909 - auc: 0.9997 - f1_score: 0.9908 - val_loss: 0.5978 - val_acc: 0.8506 - val_auc: 0.9617 - val_f1_score: 0.8454
# Epoch 62/100
# 256/256 [==============================] - 10s 37ms/step - loss: 0.0342 - acc: 0.9896 - auc: 0.9991 - f1_score: 0.9897 - val_loss: 0.2345 - val_acc: 0.9380 - val_auc: 0.9872 - val_f1_score: 0.9372
# Epoch 63/100
# 256/256 [==============================] - 10s 37ms/step - loss: 0.0284 - acc: 0.9896 - auc: 0.9997 - f1_score: 0.9897 - val_loss: 0.2221 - val_acc: 0.9443 - val_auc: 0.9882 - val_f1_score: 0.9439
# Epoch 64/100
# 256/256 [==============================] - 10s 37ms/step - loss: 0.0244 - acc: 0.9925 - auc: 0.9994 - f1_score: 0.9925 - val_loss: 0.2915 - val_acc: 0.9287 - val_auc: 0.9832 - val_f1_score: 0.9293
# Epoch 65/100
# 256/256 [==============================] - 10s 38ms/step - loss: 0.0308 - acc: 0.9906 - auc: 0.9997 - f1_score: 0.9907 - val_loss: 0.1590 - val_acc: 0.9561 - val_auc: 0.9935 - val_f1_score: 0.9559
# Epoch 66/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0201 - acc: 0.9932 - auc: 0.9997 - f1_score: 0.9933 - val_loss: 0.2394 - val_acc: 0.9380 - val_auc: 0.9880 - val_f1_score: 0.9371
# Epoch 67/100
# 256/256 [==============================] - 10s 37ms/step - loss: 0.0282 - acc: 0.9914 - auc: 0.9994 - f1_score: 0.9913 - val_loss: 0.7316 - val_acc: 0.8477 - val_auc: 0.9496 - val_f1_score: 0.8373
# Epoch 68/100
# 256/256 [==============================] - 10s 38ms/step - loss: 0.0584 - acc: 0.9818 - auc: 0.9983 - f1_score: 0.9814 - val_loss: 0.2763 - val_acc: 0.9341 - val_auc: 0.9867 - val_f1_score: 0.9338
# Epoch 69/100
# 256/256 [==============================] - 10s 37ms/step - loss: 0.0267 - acc: 0.9912 - auc: 0.9997 - f1_score: 0.9912 - val_loss: 0.1912 - val_acc: 0.9531 - val_auc: 0.9894 - val_f1_score: 0.9529
# Epoch 70/100
# 256/256 [==============================] - 10s 37ms/step - loss: 0.0182 - acc: 0.9948 - auc: 0.9997 - f1_score: 0.9948 - val_loss: 0.5882 - val_acc: 0.8652 - val_auc: 0.9573 - val_f1_score: 0.8663
# Epoch 71/100
# 256/256 [==============================] - 10s 38ms/step - loss: 0.0303 - acc: 0.9886 - auc: 0.9995 - f1_score: 0.9887 - val_loss: 0.1894 - val_acc: 0.9512 - val_auc: 0.9891 - val_f1_score: 0.9509
# Epoch 72/100
# 256/256 [==============================] - 10s 37ms/step - loss: 0.0229 - acc: 0.9920 - auc: 0.9998 - f1_score: 0.9920 - val_loss: 0.2514 - val_acc: 0.9370 - val_auc: 0.9861 - val_f1_score: 0.9369
# Epoch 73/100
# 256/256 [==============================] - 10s 38ms/step - loss: 0.0163 - acc: 0.9944 - auc: 0.9998 - f1_score: 0.9944 - val_loss: 0.2084 - val_acc: 0.9492 - val_auc: 0.9880 - val_f1_score: 0.9491
# Epoch 74/100
# 256/256 [==============================] - 9s 36ms/step - loss: 0.0207 - acc: 0.9931 - auc: 0.9995 - f1_score: 0.9931 - val_loss: 0.2677 - val_acc: 0.9331 - val_auc: 0.9851 - val_f1_score: 0.9334
# Epoch 75/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0400 - acc: 0.9849 - auc: 0.9994 - f1_score: 0.9848 - val_loss: 0.2325 - val_acc: 0.9419 - val_auc: 0.9875 - val_f1_score: 0.9413
# Epoch 76/100
# 256/256 [==============================] - 9s 36ms/step - loss: 0.0137 - acc: 0.9959 - auc: 0.9999 - f1_score: 0.9959 - val_loss: 0.3251 - val_acc: 0.9360 - val_auc: 0.9774 - val_f1_score: 0.9358
# Epoch 77/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0304 - acc: 0.9897 - auc: 0.9996 - f1_score: 0.9900 - val_loss: 0.2764 - val_acc: 0.9380 - val_auc: 0.9842 - val_f1_score: 0.9372
# Epoch 78/100
# 256/256 [==============================] - 10s 37ms/step - loss: 0.0303 - acc: 0.9901 - auc: 0.9996 - f1_score: 0.9902 - val_loss: 0.1884 - val_acc: 0.9546 - val_auc: 0.9893 - val_f1_score: 0.9546
# Epoch 79/100
# 256/256 [==============================] - 9s 36ms/step - loss: 0.0276 - acc: 0.9923 - auc: 0.9994 - f1_score: 0.9924 - val_loss: 0.2058 - val_acc: 0.9521 - val_auc: 0.9885 - val_f1_score: 0.9518
# Epoch 80/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0183 - acc: 0.9944 - auc: 0.9995 - f1_score: 0.9945 - val_loss: 0.2486 - val_acc: 0.9419 - val_auc: 0.9858 - val_f1_score: 0.9409
# Epoch 81/100
# 256/256 [==============================] - 9s 36ms/step - loss: 0.0182 - acc: 0.9947 - auc: 0.9996 - f1_score: 0.9947 - val_loss: 0.9214 - val_acc: 0.8306 - val_auc: 0.9362 - val_f1_score: 0.8182
# Epoch 82/100
# 256/256 [==============================] - 10s 38ms/step - loss: 0.0266 - acc: 0.9909 - auc: 0.9991 - f1_score: 0.9909 - val_loss: 0.2359 - val_acc: 0.9497 - val_auc: 0.9857 - val_f1_score: 0.9498
# Epoch 83/100
# 256/256 [==============================] - 9s 36ms/step - loss: 0.0225 - acc: 0.9932 - auc: 0.9996 - f1_score: 0.9933 - val_loss: 0.2239 - val_acc: 0.9487 - val_auc: 0.9861 - val_f1_score: 0.9483
# Epoch 84/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0183 - acc: 0.9946 - auc: 0.9997 - f1_score: 0.9946 - val_loss: 0.1809 - val_acc: 0.9536 - val_auc: 0.9915 - val_f1_score: 0.9534
# Epoch 85/100
# 256/256 [==============================] - 10s 38ms/step - loss: 0.0185 - acc: 0.9941 - auc: 0.9999 - f1_score: 0.9941 - val_loss: 0.2297 - val_acc: 0.9443 - val_auc: 0.9876 - val_f1_score: 0.9437
# Epoch 86/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0176 - acc: 0.9949 - auc: 0.9998 - f1_score: 0.9949 - val_loss: 0.1940 - val_acc: 0.9546 - val_auc: 0.9906 - val_f1_score: 0.9544
# Epoch 87/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0095 - acc: 0.9972 - auc: 0.9999 - f1_score: 0.9972 - val_loss: 0.2049 - val_acc: 0.9546 - val_auc: 0.9887 - val_f1_score: 0.9548
# Epoch 88/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0174 - acc: 0.9951 - auc: 0.9997 - f1_score: 0.9950 - val_loss: 0.2450 - val_acc: 0.9458 - val_auc: 0.9862 - val_f1_score: 0.9453
# Epoch 89/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0096 - acc: 0.9966 - auc: 1.0000 - f1_score: 0.9966 - val_loss: 0.3414 - val_acc: 0.9248 - val_auc: 0.9795 - val_f1_score: 0.9244
# Epoch 90/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0231 - acc: 0.9948 - auc: 0.9992 - f1_score: 0.9949 - val_loss: 0.2507 - val_acc: 0.9453 - val_auc: 0.9863 - val_f1_score: 0.9447
# Epoch 91/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0367 - acc: 0.9885 - auc: 0.9991 - f1_score: 0.9886 - val_loss: 0.3429 - val_acc: 0.9131 - val_auc: 0.9821 - val_f1_score: 0.9118
# Epoch 92/100
# 256/256 [==============================] - 10s 38ms/step - loss: 0.0307 - acc: 0.9894 - auc: 0.9993 - f1_score: 0.9894 - val_loss: 0.2094 - val_acc: 0.9497 - val_auc: 0.9890 - val_f1_score: 0.9493
# Epoch 93/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0153 - acc: 0.9957 - auc: 0.9996 - f1_score: 0.9957 - val_loss: 0.2798 - val_acc: 0.9409 - val_auc: 0.9826 - val_f1_score: 0.9407
# Epoch 94/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0199 - acc: 0.9942 - auc: 0.9996 - f1_score: 0.9942 - val_loss: 0.1874 - val_acc: 0.9570 - val_auc: 0.9897 - val_f1_score: 0.9571
# Epoch 95/100
# 256/256 [==============================] - 10s 37ms/step - loss: 0.0221 - acc: 0.9949 - auc: 0.9991 - f1_score: 0.9948 - val_loss: 0.4044 - val_acc: 0.9214 - val_auc: 0.9735 - val_f1_score: 0.9192
# Epoch 96/100
# 256/256 [==============================] - 9s 36ms/step - loss: 0.0173 - acc: 0.9946 - auc: 0.9995 - f1_score: 0.9946 - val_loss: 0.2239 - val_acc: 0.9478 - val_auc: 0.9885 - val_f1_score: 0.9476
# Epoch 97/100
# 256/256 [==============================] - 9s 36ms/step - loss: 0.0155 - acc: 0.9946 - auc: 0.9999 - f1_score: 0.9947 - val_loss: 0.2551 - val_acc: 0.9404 - val_auc: 0.9862 - val_f1_score: 0.9399
# Epoch 98/100
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0150 - acc: 0.9978 - auc: 0.9995 - f1_score: 0.9978 - val_loss: 0.3212 - val_acc: 0.9360 - val_auc: 0.9802 - val_f1_score: 0.9351
# Epoch 99/100
# 256/256 [==============================] - 10s 37ms/step - loss: 0.0133 - acc: 0.9954 - auc: 0.9999 - f1_score: 0.9954 - val_loss: 0.2641 - val_acc: 0.9468 - val_auc: 0.9840 - val_f1_score: 0.9466
# Epoch 100/100
# 256/256 [==============================] - 9s 36ms/step - loss: 0.0302 - acc: 0.9921 - auc: 0.9991 - f1_score: 0.9921 - val_loss: 0.2064 - val_acc: 0.9502 - val_auc: 0.9898 - val_f1_score: 0.9499

# %%
#Plotting the trend of the metrics during training

fig, ax = plt.subplots(1, 3, figsize = (30, 5))
ax = ax.ravel()

for i, metric in enumerate(["acc", "auc", "loss"]):
    ax[i].plot(history.history[metric])
    ax[i].plot(history.history["val_" + metric])
    ax[i].set_title("Model {}".format(metric))
    ax[i].set_xlabel("Epochs")
    ax[i].set_ylabel(metric)
    ax[i].legend(["train", "val"])

# %%
#Evaluating the model on the data

#train_scores = model.evaluate(train_data, train_labels)
#val_scores = model.evaluate(val_data, val_labels)
test_scores = model.evaluate(test_data, test_labels)

#print("Training Accuracy: %.2f%%"%(train_scores[1] * 100))
#print("Validation Accuracy: %.2f%%"%(val_scores[1] * 100))
print("Testing Accuracy: %.2f%%"%(test_scores[1] * 100))
# Out:
# 80/80 [==============================] - 1s 13ms/step - loss: 0.1882 - acc: 0.9484 - auc: 0.9911 - f1_score: 0.9483
# Testing Accuracy: 94.84%

# %%
#Predicting the test data

pred_labels = model.predict(test_data)

# %%
#Print the classification report of the tested data

#Since the labels are softmax arrays, we need to roundoff to have it in the form of 0s and 1s,
#similar to the test_labels
def roundoff(arr):
    """To round off according to the argmax of each predicted label array. """
    arr[np.argwhere(arr != arr.max())] = 0
    arr[np.argwhere(arr == arr.max())] = 1
    return arr

for labels in pred_labels:
    labels = roundoff(labels)

print(classification_report(test_labels, pred_labels, target_names=CLASSES))
# Out:
#                   precision    recall  f1-score   support
#
#      NonDemented       0.96      1.00      0.98       639
# VeryMildDemented       1.00      1.00      1.00       635
#     MildDemented       0.93      0.89      0.91       662
# ModerateDemented       0.90      0.91      0.90       624
#
#        micro avg       0.95      0.95      0.95      2560
#        macro avg       0.95      0.95      0.95      2560
#     weighted avg       0.95      0.95      0.95      2560
#      samples avg       0.95      0.95      0.95      2560

# %%
#Plot the confusion matrix to understand the classification in detail

pred_ls = np.argmax(pred_labels, axis=1)
test_ls = np.argmax(test_labels, axis=1)

conf_arr = confusion_matrix(test_ls, pred_ls)

plt.figure(figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

ax = sns.heatmap(conf_arr, cmap='Greens', annot=True, fmt='d', xticklabels=CLASSES, yticklabels=CLASSES)

plt.title('Alzheimer\'s Disease Diagnosis')
plt.xlabel('Prediction')
plt.ylabel('Truth')
plt.show(ax)

# %%
#Printing some other classification metrics

print("Balanced Accuracy Score: {} %".format(round(BAS(test_ls, pred_ls) * 100, 2)))
print("Matthew's Correlation Coefficient: {} %".format(round(MCC(test_ls, pred_ls) * 100, 2)))
# Out:
# Balanced Accuracy Score: 94.88 %
# Matthew's Correlation Coefficient: 93.14 %

# %%
#Saving the model for future use

model_dir = work_dir + "alzheimer_cnn_model"
model.save(model_dir, save_format='h5')
